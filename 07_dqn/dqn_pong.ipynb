# %% [markdown]
# # [07] Deep Q-Learning in Pong
#
# ### Imports & Constants

# %%
import time, datetime, collections, os
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter

from lib import wrappers, dqn_model


DEFAULT_ENV_NAME = "PongNoFrameskip-v4"
MEAN_REWARD_BOUND = 19  # Mean reward boundary 

GAMMA = 0.99  # Used for bellman approximation 
BATCH_SIZE = 32  # Batch size to be sampled from replay buffer 
REPLAY_SIZE = 10000  # Maximum size of replay buffer 

LEARNING_RATE = 1e-4
REPLAY_START_SIZE = 10000  # Number of frames we wait for, before starting training, to fill the replay buffer 

# Model sync freqeuncy (from training model --> to target model)
# Used to get the value of the next state 
SYNC_TARGET_FRAMES = 1000  


EPSILON_START = 1.0  # Start by selecting all actions randomly 

# In the first `EPSILON_DECAY_LAST_FRAME` frames, epsilon decays to 0.01
# This corresponds to a random action taken on 1% of the steps 
EPSILON_DECAY_LAST_FRAME = 150000
EPSILON_FINAL = 0.01

# %% [markdown]
# <br>
#
# ### Sanity-Checking
#
# ##### Calculating Conv2D Dimensions
# <img src='images/conv2d_dimension_calculation.png' style="width:700px;height:400px;">
#
# ##### Testing `__init__`

# %%
env = wrappers.make_env(DEFAULT_ENV_NAME)
input_shape = env.observation_space.shape
n_actions = env.action_space.n
model = dqn_model.DQN(input_shape, n_actions)
print(model)
# Out:
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
# )

# %% [markdown]
# ##### Testing `_get_conv_out`

# %%
conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4), # (4, 84, 84) --> (32, 20, 20)
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2), # (32, 20, 20) --> (64, 9, 9)
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1), # (64, 9, 9) --> (64, 7, 7)
            nn.ReLU()
        )
o = conv(torch.zeros(1, *input_shape))
num_parameters = int(np.prod(o.size()))

print(input_shape)
print(o.size())
print(num_parameters)
# Out:
# (4, 84, 84)
# torch.Size([1, 64, 7, 7])
# 3136

# %% [markdown]
# ##### Testing `forward`

# %%
fc = nn.Sequential(
            nn.Linear(3136, 512), # 3136 --> 512
            nn.ReLU(),
            nn.Linear(512, n_actions) # 512 --> 6
        )

state = env.reset()
state_a = np.array([state], copy=False)
state_v = torch.tensor(state_a)

conv_out = conv(state_v).view(state_v.size()[0], -1) # (1, 4, 84, 84) --> (1, 3136)
fc_out = fc(conv_out) # (1, 3136) --> (1, 6)

print(state.shape)
print(state_v.shape)
print(conv_out.shape)
print(fc_out.shape)
# Out:
# (4, 84, 84)
# torch.Size([1, 4, 84, 84])
# torch.Size([1, 3136])
# torch.Size([1, 6])

# %% [markdown]
# <br>
#
# ### Experience Replay Buffer

# %%
Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

class ExperienceBuffer:
    '''Experience Replay Buffer to break correlations between subsequent steps in the environment'''
    
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        '''Appends `experience` to breplay buffer'''
        
        self.buffer.append(experience)

    def sample(self, batch_size):
        '''
        Samples `batch_size` number of experiences from the buffer
        Requirement: len(self.buffer) > batch_size
        '''
        
        # Create list of random indices (from 1-`len(self.buffer)`) of size `batch_size`
        # Note: Without replacement, so there CAN'T be duplicates
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        
        # Sample experience tuples from buffers 
        # Then split them up in: `states`, `actions`, `rewards`, `dones`, and `next_states`
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        
        return np.array(states), \
               np.array(actions), \
               np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), \
               np.array(next_states)

# %% [markdown]
# ##### Testing `ExperienceBuffer`

# %%
buffer = collections.deque(maxlen=100)
buffer.append(("s0", "a0", "r0", "d0", "s'0"))
buffer.append(("s1", "a1", "r1", "d1", "s'1"))
buffer.append(("s2", "a2", "r2", "d2", "s'2"))
buffer.append(("s3", "a3", "r3", "d3", "s'3"))

batch_size=2
indices = np.random.choice(len(buffer), batch_size, replace=False)
states, actions, rewards, dones, next_states = zip(*[buffer[idx] for idx in indices])

print(indices)
print([buffer[idx] for idx in indices])
print(states, actions, rewards, dones, next_states)
print(np.array(states), np.array(actions), np.array(rewards), np.array(dones), np.array(next_states))
# Out:
# [2 3]
# [('s2', 'a2', 'r2', 'd2', "s'2"), ('s3', 'a3', 'r3', 'd3', "s'3")]
# ('s2', 's3') ('a2', 'a3') ('r2', 'r3') ('d2', 'd3') ("s'2", "s'3")
# ['s2' 's3'] ['a2' 'a3'] ['r2' 'r3'] ['d2' 'd3'] ["s'2" "s'3"]

# %% [markdown]
# <br>
#
# ### Agent

# %%
class Agent:
    def __init__(self, env, exp_buffer):
        self.env = env  # Environment 
        self.exp_buffer = exp_buffer  # Replay Buffer 
        self._reset()  # Reset the `state` and `total_reward` 

    def _reset(self):
        '''Resets environment and reward '''
        
        self.state = env.reset()
        self.total_reward = 0.0

    @torch.no_grad()
    def play_step(self, net, epsilon=0.0, device="cpu"):
        '''Takes a step in the environment'''
        
        done_reward = None

        # Epsilon-Greedy Policy 
        if np.random.random() < epsilon:
            
            # Take random action 
            action = env.action_space.sample()
            
        else:
            
            # Get Q_values for all possible actions and choose the best one 
            state_a = np.array([self.state], copy=False)  # Action 
            state_v = torch.tensor(state_a).to(device)  # Action tensor
            q_vals_v = net(state_v)  # Q-values (tensor)
            _, act_v = torch.max(q_vals_v, dim=1)  # Highest Q-value (tensor)
            action = int(act_v.item())  # Extracting value 

        # Take step 
        new_state, reward, is_done, _ = self.env.step(action)
        self.total_reward += reward

        # Save experience 
        exp = Experience(self.state, action, reward, is_done, new_state)
        self.exp_buffer.append(exp)
        
        # Prepare for next step 
        self.state = new_state
        
        # If environment is over 
        if is_done:
            done_reward = self.total_reward
            self._reset()
            
        return done_reward

# %% [markdown]
# ##### Testing `Agent`

# %%
env = wrappers.make_env(DEFAULT_ENV_NAME)
state = env.reset()
total_reward = 0

state_a = np.array([state], copy=False)
state_v = torch.tensor(state_a)
q_vals_v = model(state_v)
_, act_v = torch.max(q_vals_v, dim=1)
action = int(act_v.item())

print('Action Shape: \t\t', state_a.shape)
print('Action Tensor Shape: \t', state_v.shape)
print('Q-Values: \t\t', q_vals_v.data)
print('Highest Q-Value: \t', act_v)
print('Best Action: \t\t', action)
# Out:
# Action Shape: 		 (1, 4, 84, 84)
# Action Tensor Shape: 	 torch.Size([1, 4, 84, 84])
# Q-Values: 		 tensor([[-0.0343,  0.0217, -0.0394, -0.0175,  0.0236,  0.0226]])
# Highest Q-Value: 	 tensor([4])
# Best Action: 		 4

# %% [markdown]
# <br>
#
# ### Calculate Loss
#
# For steps not at the end of te episode:
# $ L = \Big( Q(s,a) - \big(r + \gamma \max_{a' \in A} \hat{Q}(s',a') \big) \Big)^2 $
# For final steps:
# $ L = \big( Q(s, a) - r \big)^2 $

# %%
def calc_loss(batch, net, tgt_net, device="cpu"):
    '''
    Calculates loss for a batch of experiences
    
    net: 
    - Network we're training
    - Used to calculate gradients
    
    tgt_net: 
    - Target Network
    - Is periodically synced with `net`
    - Calculates values for the next states (this doesn't affect the gradients)
    '''
    
    # Extract `states`, `actions`, `rewards`, `dones`, and `next_states`
    states, actions, rewards, dones, next_states = batch

    # Convert to tensors and move to `device`
    states_v = torch.tensor(np.array(states, copy=False)).to(device) 
    next_states_v = torch.tensor(np.array(next_states, copy=False)).to(device) 
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done_mask = torch.BoolTensor(dones).to(device)

    # Get Q-values for states
    # `actions_v.unsqueeze(-1)`: Tensor of indices of elements to be chosen 
    # `squeeze(-1)`: Remove unnecessary dimensions 
    # Note: `gather` keeps all gradients
    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    
    with torch.no_grad():
        
        # Calculate maximum Q-values for next states, along action-dimension (1)
        # Note: `.max` calculates max values and their indices, but we only want max values, so we index [0]
        next_state_values = tgt_net(next_states_v).max(1)[0]
        
        # ? 
        next_state_values[done_mask] = 0.0
        
        # `detach` prevents gradients from flowing into the `tgt_net`'s graph
        next_state_values = next_state_values.detach()

    # Bellman approximation 
    expected_state_action_values = next_state_values * GAMMA + rewards_v
    
    # Mean squared error loss 
    return nn.MSELoss()(state_action_values, expected_state_action_values)

# %% [markdown]
# `state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)`:
#
# <img src="images/gather.png" style="height:200px">
#
# ##### Testing `calc_loss`

# %%
import pprint

buffer = ExperienceBuffer(100)
buffer.append(Experience(0, 0, 0, False, 1))
buffer.append(Experience(1, 1, 1, False, 2))
buffer.append(Experience(2, 2, 2, False, 3))
buffer.append(Experience(3, 3, 3, False, 4))
batch = buffer.sample(2)

states, actions, rewards, dones, next_states = batch

states_v = torch.tensor(np.array(states, copy=False))
next_states_v = torch.tensor(np.array(next_states, copy=False))
actions_v = torch.tensor(actions)
rewards_v = torch.tensor(rewards)
done_mask = torch.BoolTensor(dones)

pprint.pprint(batch)
print('\nStates: \t', states_v)
print('Next States: \t', next_states_v)
print('Actions: \t', actions_v)
print('Rewards: \t', rewards_v)
print('Dones: \t\t', done_mask)

print('\nactions_v.shape: \t\t', actions_v.shape)
print('actions_v.unsqueeze(-1).shape: \t', actions_v.unsqueeze(-1).shape)
# Out:
# (array([2, 1]),
#  array([2, 1]),
#  array([2., 1.], dtype=float32),
#  array([0, 0], dtype=uint8),
#  array([3, 2]))
#
# States: 	 tensor([2, 1])
# Next States: 	 tensor([3, 2])
# Actions: 	 tensor([2, 1])
# Rewards: 	 tensor([2., 1.])
# Dones: 		 tensor([False, False])
#
# actions_v.shape: 		 torch.Size([2])
# actions_v.unsqueeze(-1).shape: 	 torch.Size([2, 1])

# %% [markdown]
# <br>
#
# ### Main

# %%
### GPU/CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Environment
env = wrappers.make_env(DEFAULT_ENV_NAME)
env_name = env.unwrapped.spec.id

# TensorBoard
log_dir = os.path.join('runs', datetime.datetime.now().strftime("%Y:%m:%d-%H:%M:%S"))
writer = SummaryWriter(log_dir)

model_dir = 'models/'

# Recording 
# rec_dir = "./recordings/07_recording"
# recording = gym.wrappers.monitoring.video_recorder.VideoRecorder(env, base_path=rec_dir)

net = dqn_model.DQN(env.observation_space.shape, env.action_space.n).to(device) # (Training) Network: Calculates gradients 
tgt_net = dqn_model.DQN(env.observation_space.shape, env.action_space.n).to(device) # Target Network: Calculates Q-values for the next states 
print(net, ' \n')

buffer = ExperienceBuffer(REPLAY_SIZE) # Replay buffer 
agent = Agent(env, buffer) # Agent 
epsilon = EPSILON_START # Initial epsilon 

optimizer = optim.Adam(net.parameters(), lr=LEARNING_RATE) 
total_rewards = [] # All (done-)rewards 
frame_idx = 0 # Frame counter (used when there's a reward and env is over)
ts_frame = 0 # Time counter (used when there's a reward and env is over)
ts = time.time() # Current time 
best_m_reward = None # Best mean reward 

while True:
    
    env.render()
    # recording.caputre_frame()
    
    # Increment number of iterations 
    frame_idx += 1
    
    # Decrease `epsilon` linearly from 0-`EPSILON_DECAY_LAST_FRAME`, then keep it constant at `EPSILON_FINAL`
    epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)

    # Take step using current network 
    reward = agent.play_step(net, epsilon, device=device)    
    
    # If this stpe is the last step in the episode 
    if reward is not None:
        
        # Keep track of reward given 
        total_rewards.append(reward)
        
        # Calculate speed (as number of fps) 
        speed = (frame_idx - ts_frame) / (time.time() - ts)
        
        # Number of episodes played and current time 
        ts_frame = frame_idx
        ts = time.time()
        
        # Mean reward for last 100 episodes 
        m_reward = np.mean(total_rewards[-100:])
        
        # Print & Save to TensorBord 
        print("Frame #%d: \tdone %d games, \treward %.3f, \tepsilon %.2f, \tspeed %.2f f/s" % (frame_idx, len(total_rewards), m_reward, epsilon, speed))
        writer.add_scalar("epsilon", epsilon, frame_idx)
        writer.add_scalar("speed", speed, frame_idx)
        writer.add_scalar("reward_100", m_reward, frame_idx)
        writer.add_scalar("reward", reward, frame_idx)
        
        # If the mean reward for the alst 100 episodes is a maximum 
        if best_m_reward is None or best_m_reward < m_reward:
            
            # Save model (rounds up/down)
            torch.save(net.state_dict(), model_dir + env_name + "_%.0f.dat" % m_reward)
                
            if best_m_reward is not None:
                print("\nBest reward updated %.3f -> %.3f\n" % (best_m_reward, m_reward))
            
            # Save mean reward 
            best_m_reward = m_reward
        
        # If the mean reward exceeds the boundary, stop training 
        if m_reward > MEAN_REWARD_BOUND:
            print("Solved in %d frames!" % frame_idx)
            break

    # If buffer ISN'T large enough for training, skip training 
    if len(buffer) < REPLAY_START_SIZE:
        continue

    # Every `SYNC_TARGET_FRAMES`, sync parameters from main network to target network 
    if frame_idx % SYNC_TARGET_FRAMES == 0:
        tgt_net.load_state_dict(net.state_dict())

    # Zero gradients, sample batch from buffer, calculate loss, optimize & minimize loss (for `net`)
    optimizer.zero_grad()
    batch = buffer.sample(BATCH_SIZE)
    loss_t = calc_loss(batch, net, tgt_net, device=device)
    loss_t.backward()
    optimizer.step()
        
writer.close()
# recording.close()
# Out:
# DQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=6, bias=True)
#   )
# )
#
# Frame #944: 	done 1 games, 	reward -21.000, 	epsilon 0.99, 	speed 232.34 f/s
# Frame #1872: 	done 2 games, 	reward -20.500, 	epsilon 0.99, 	speed 274.93 f/s
#
# Best reward updated -21.000 -> -20.500
#
# Frame #2662: 	done 3 games, 	reward -20.667, 	epsilon 0.98, 	speed 301.69 f/s
# Frame #3593: 	done 4 games, 	reward -20.750, 	epsilon 0.98, 	speed 498.88 f/s
# Frame #4550: 	done 5 games, 	reward -20.600, 	epsilon 0.97, 	speed 490.56 f/s
# Frame #5490: 	done 6 games, 	reward -20.667, 	epsilon 0.96, 	speed 421.10 f/s
# Frame #6252: 	done 7 games, 	reward -20.714, 	epsilon 0.96, 	speed 410.33 f/s
# Frame #7134: 	done 8 games, 	reward -20.750, 	epsilon 0.95, 	speed 416.40 f/s
# Frame #7997: 	done 9 games, 	reward -20.667, 	epsilon 0.95, 	speed 370.26 f/s
# Frame #8788: 	done 10 games, 	reward -20.700, 	epsilon 0.94, 	speed 445.78 f/s
# Frame #9638: 	done 11 games, 	reward -20.727, 	epsilon 0.94, 	speed 453.04 f/s
# Frame #10508: 	done 12 games, 	reward -20.667, 	epsilon 0.93, 	speed 30.55 f/s
# Frame #11567: 	done 13 games, 	reward -20.538, 	epsilon 0.92, 	speed 16.93 f/s
# Frame #12417: 	done 14 games, 	reward -20.571, 	epsilon 0.92, 	speed 17.35 f/s
# Frame #13454: 	done 15 games, 	reward -20.467, 	epsilon 0.91, 	speed 17.25 f/s
#
# Best reward updated -20.500 -> -20.467
#
# Frame #14449: 	done 16 games, 	reward -20.375, 	epsilon 0.90, 	speed 17.24 f/s
#
# Best reward updated -20.467 -> -20.375
#
# Frame #15421: 	done 17 games, 	reward -20.412, 	epsilon 0.90, 	speed 16.75 f/s
# Frame #16365: 	done 18 games, 	reward -20.389, 	epsilon 0.89, 	speed 16.62 f/s
# Frame #17215: 	done 19 games, 	reward -20.421, 	epsilon 0.89, 	speed 16.49 f/s
# Frame #18215: 	done 20 games, 	reward -20.350, 	epsilon 0.88, 	speed 16.48 f/s
#
# Best reward updated -20.375 -> -20.350
#
# Frame #19160: 	done 21 games, 	reward -20.333, 	epsilon 0.87, 	speed 16.36 f/s
#
# Best reward updated -20.350 -> -20.333
#
# Frame #20223: 	done 22 games, 	reward -20.273, 	epsilon 0.87, 	speed 16.29 f/s
#
# Best reward updated -20.333 -> -20.273
#
# Frame #21105: 	done 23 games, 	reward -20.304, 	epsilon 0.86, 	speed 16.48 f/s
# Frame #21987: 	done 24 games, 	reward -20.333, 	epsilon 0.85, 	speed 16.32 f/s
# Frame #23051: 	done 25 games, 	reward -20.320, 	epsilon 0.85, 	speed 16.31 f/s
# Frame #23901: 	done 26 games, 	reward -20.346, 	epsilon 0.84, 	speed 16.42 f/s
# Frame #24846: 	done 27 games, 	reward -20.333, 	epsilon 0.83, 	speed 16.43 f/s
# Frame #25696: 	done 28 games, 	reward -20.357, 	epsilon 0.83, 	speed 16.39 f/s
# Frame #26699: 	done 29 games, 	reward -20.345, 	epsilon 0.82, 	speed 16.40 f/s
# Frame #27643: 	done 30 games, 	reward -20.333, 	epsilon 0.82, 	speed 16.30 f/s
# Frame #28424: 	done 31 games, 	reward -20.355, 	epsilon 0.81, 	speed 16.32 f/s
# Frame #29712: 	done 32 games, 	reward -20.312, 	epsilon 0.80, 	speed 16.33 f/s
# Frame #30764: 	done 33 games, 	reward -20.303, 	epsilon 0.79, 	speed 16.35 f/s
# Frame #31742: 	done 34 games, 	reward -20.294, 	epsilon 0.79, 	speed 16.35 f/s
# Frame #32649: 	done 35 games, 	reward -20.314, 	epsilon 0.78, 	speed 16.45 f/s
# Frame #33575: 	done 36 games, 	reward -20.333, 	epsilon 0.78, 	speed 16.51 f/s
# Frame #34706: 	done 37 games, 	reward -20.297, 	epsilon 0.77, 	speed 16.52 f/s
# Frame #35782: 	done 38 games, 	reward -20.263, 	epsilon 0.76, 	speed 16.54 f/s
#
# Best reward updated -20.273 -> -20.263
#
# Frame #36798: 	done 39 games, 	reward -20.256, 	epsilon 0.75, 	speed 16.49 f/s
#
# Best reward updated -20.263 -> -20.256
#
# Frame #37871: 	done 40 games, 	reward -20.250, 	epsilon 0.75, 	speed 16.48 f/s
#
# Best reward updated -20.256 -> -20.250
#
# Frame #38969: 	done 41 games, 	reward -20.268, 	epsilon 0.74, 	speed 16.47 f/s
# Frame #39791: 	done 42 games, 	reward -20.286, 	epsilon 0.73, 	speed 16.46 f/s
# Frame #40861: 	done 43 games, 	reward -20.279, 	epsilon 0.73, 	speed 16.42 f/s
# Frame #41849: 	done 44 games, 	reward -20.250, 	epsilon 0.72, 	speed 16.38 f/s
# Frame #42835: 	done 45 games, 	reward -20.244, 	epsilon 0.71, 	speed 16.58 f/s
#
# Best reward updated -20.250 -> -20.244
#
# Frame #44041: 	done 46 games, 	reward -20.196, 	epsilon 0.71, 	speed 16.51 f/s
#
# Best reward updated -20.244 -> -20.196
#
# Frame #44972: 	done 47 games, 	reward -20.213, 	epsilon 0.70, 	speed 15.42 f/s
# Frame #45993: 	done 48 games, 	reward -20.208, 	epsilon 0.69, 	speed 16.49 f/s
# Frame #47162: 	done 49 games, 	reward -20.184, 	epsilon 0.69, 	speed 16.49 f/s
#
# Best reward updated -20.196 -> -20.184
#
# Frame #48433: 	done 50 games, 	reward -20.180, 	epsilon 0.68, 	speed 16.39 f/s
#
# Best reward updated -20.184 -> -20.180
#
# Frame #49387: 	done 51 games, 	reward -20.196, 	epsilon 0.67, 	speed 16.34 f/s
# Frame #50825: 	done 52 games, 	reward -20.135, 	epsilon 0.66, 	speed 16.23 f/s
#
# Best reward updated -20.180 -> -20.135
#
# Frame #52227: 	done 53 games, 	reward -20.094, 	epsilon 0.65, 	speed 16.48 f/s
#
# Best reward updated -20.135 -> -20.094
#
# Frame #53300: 	done 54 games, 	reward -20.074, 	epsilon 0.64, 	speed 16.55 f/s
#
# Best reward updated -20.094 -> -20.074
#
# Frame #54570: 	done 55 games, 	reward -20.036, 	epsilon 0.64, 	speed 16.51 f/s
#
# Best reward updated -20.074 -> -20.036
#
# Frame #56071: 	done 56 games, 	reward -19.946, 	epsilon 0.63, 	speed 16.49 f/s
#
# Best reward updated -20.036 -> -19.946
#
# Frame #57121: 	done 57 games, 	reward -19.965, 	epsilon 0.62, 	speed 16.44 f/s
# Frame #58307: 	done 58 games, 	reward -19.966, 	epsilon 0.61, 	speed 16.38 f/s
# Frame #59591: 	done 59 games, 	reward -19.949, 	epsilon 0.60, 	speed 16.34 f/s
# Frame #61236: 	done 60 games, 	reward -19.900, 	epsilon 0.59, 	speed 16.23 f/s
#
# Best reward updated -19.946 -> -19.900
#
# Frame #62402: 	done 61 games, 	reward -19.902, 	epsilon 0.58, 	speed 16.30 f/s
# Frame #63465: 	done 62 games, 	reward -19.903, 	epsilon 0.58, 	speed 16.16 f/s
# Frame #64796: 	done 63 games, 	reward -19.873, 	epsilon 0.57, 	speed 16.19 f/s
#
# Best reward updated -19.900 -> -19.873
#
# Frame #66058: 	done 64 games, 	reward -19.875, 	epsilon 0.56, 	speed 16.03 f/s
# Frame #67331: 	done 65 games, 	reward -19.846, 	epsilon 0.55, 	speed 15.93 f/s
#
# Best reward updated -19.873 -> -19.846
#
# Frame #68408: 	done 66 games, 	reward -19.848, 	epsilon 0.54, 	speed 15.88 f/s
# Frame #69506: 	done 67 games, 	reward -19.866, 	epsilon 0.54, 	speed 15.83 f/s
# Frame #70821: 	done 68 games, 	reward -19.853, 	epsilon 0.53, 	speed 15.66 f/s
# Frame #72307: 	done 69 games, 	reward -19.841, 	epsilon 0.52, 	speed 15.62 f/s
#
# Best reward updated -19.846 -> -19.841
#
# Frame #73509: 	done 70 games, 	reward -19.843, 	epsilon 0.51, 	speed 15.56 f/s
# Frame #75219: 	done 71 games, 	reward -19.775, 	epsilon 0.50, 	speed 15.35 f/s
#
# Best reward updated -19.841 -> -19.775
#
# Frame #76541: 	done 72 games, 	reward -19.764, 	epsilon 0.49, 	speed 15.16 f/s
#
# Best reward updated -19.775 -> -19.764
#
# Frame #78076: 	done 73 games, 	reward -19.726, 	epsilon 0.48, 	speed 15.03 f/s
#
# Best reward updated -19.764 -> -19.726
#
# Frame #79308: 	done 74 games, 	reward -19.703, 	epsilon 0.47, 	speed 14.83 f/s
#
# Best reward updated -19.726 -> -19.703
#
# Frame #80555: 	done 75 games, 	reward -19.680, 	epsilon 0.46, 	speed 14.29 f/s
#
# Best reward updated -19.703 -> -19.680
#
# Frame #81894: 	done 76 games, 	reward -19.671, 	epsilon 0.45, 	speed 14.49 f/s
#
# Best reward updated -19.680 -> -19.671
#
# Frame #83278: 	done 77 games, 	reward -19.623, 	epsilon 0.44, 	speed 14.51 f/s
#
# Best reward updated -19.671 -> -19.623
#
# Frame #84948: 	done 78 games, 	reward -19.564, 	epsilon 0.43, 	speed 14.57 f/s
#
# Best reward updated -19.623 -> -19.564
#
# Frame #86384: 	done 79 games, 	reward -19.557, 	epsilon 0.42, 	speed 14.44 f/s
#
# Best reward updated -19.564 -> -19.557
#
# Frame #87952: 	done 80 games, 	reward -19.512, 	epsilon 0.41, 	speed 14.49 f/s
#
# Best reward updated -19.557 -> -19.512
#
# Frame #89296: 	done 81 games, 	reward -19.519, 	epsilon 0.40, 	speed 14.26 f/s
# Frame #90977: 	done 82 games, 	reward -19.488, 	epsilon 0.39, 	speed 14.28 f/s
#
# Best reward updated -19.512 -> -19.488
#
# Frame #92574: 	done 83 games, 	reward -19.446, 	epsilon 0.38, 	speed 14.38 f/s
#
# Best reward updated -19.488 -> -19.446
#
# Frame #93910: 	done 84 games, 	reward -19.417, 	epsilon 0.37, 	speed 14.55 f/s
#
# Best reward updated -19.446 -> -19.417
#
# Frame #95588: 	done 85 games, 	reward -19.376, 	epsilon 0.36, 	speed 14.67 f/s
#
# Best reward updated -19.417 -> -19.376
#
# Frame #96944: 	done 86 games, 	reward -19.384, 	epsilon 0.35, 	speed 14.57 f/s
# Frame #98747: 	done 87 games, 	reward -19.345, 	epsilon 0.34, 	speed 14.71 f/s
#
# Best reward updated -19.376 -> -19.345
#
# Frame #100010: 	done 88 games, 	reward -19.352, 	epsilon 0.33, 	speed 14.72 f/s
# Frame #101585: 	done 89 games, 	reward -19.315, 	epsilon 0.32, 	speed 14.67 f/s
#
# Best reward updated -19.345 -> -19.315
#
# Frame #103665: 	done 90 games, 	reward -19.256, 	epsilon 0.31, 	speed 14.66 f/s
#
# Best reward updated -19.315 -> -19.256
#
# Frame #105743: 	done 91 games, 	reward -19.187, 	epsilon 0.30, 	speed 14.66 f/s
#
# Best reward updated -19.256 -> -19.187
#
# Frame #107468: 	done 92 games, 	reward -19.163, 	epsilon 0.28, 	speed 14.70 f/s
#
# Best reward updated -19.187 -> -19.163
#
# Frame #109571: 	done 93 games, 	reward -19.118, 	epsilon 0.27, 	speed 14.58 f/s
#
# Best reward updated -19.163 -> -19.118
#
# Frame #111522: 	done 94 games, 	reward -19.074, 	epsilon 0.26, 	speed 14.60 f/s
#
# Best reward updated -19.118 -> -19.074
#
# Frame #113489: 	done 95 games, 	reward -19.063, 	epsilon 0.24, 	speed 14.59 f/s
#
# Best reward updated -19.074 -> -19.063
#
# Frame #115778: 	done 96 games, 	reward -18.958, 	epsilon 0.23, 	speed 14.60 f/s
#
# Best reward updated -19.063 -> -18.958
#
# Frame #117664: 	done 97 games, 	reward -18.928, 	epsilon 0.22, 	speed 14.61 f/s
#
# Best reward updated -18.958 -> -18.928
#
# Frame #119557: 	done 98 games, 	reward -18.888, 	epsilon 0.20, 	speed 14.56 f/s
#
# Best reward updated -18.928 -> -18.888
#
# Frame #121512: 	done 99 games, 	reward -18.848, 	epsilon 0.19, 	speed 14.59 f/s
#
# Best reward updated -18.888 -> -18.848
#
# Frame #123281: 	done 100 games, 	reward -18.830, 	epsilon 0.18, 	speed 14.47 f/s
#
# Best reward updated -18.848 -> -18.830
#
# Frame #125484: 	done 101 games, 	reward -18.790, 	epsilon 0.16, 	speed 14.53 f/s
#
# Best reward updated -18.830 -> -18.790
#
# Frame #127092: 	done 102 games, 	reward -18.740, 	epsilon 0.15, 	speed 14.55 f/s
#
# Best reward updated -18.790 -> -18.740
#
# Frame #128952: 	done 103 games, 	reward -18.700, 	epsilon 0.14, 	speed 14.38 f/s
#
# Best reward updated -18.740 -> -18.700
#
# Frame #131788: 	done 104 games, 	reward -18.570, 	epsilon 0.12, 	speed 13.99 f/s
#
# Best reward updated -18.700 -> -18.570
#
# Frame #134347: 	done 105 games, 	reward -18.490, 	epsilon 0.10, 	speed 14.16 f/s
#
# Best reward updated -18.570 -> -18.490
#
# Frame #136703: 	done 106 games, 	reward -18.380, 	epsilon 0.09, 	speed 14.53 f/s
#
# Best reward updated -18.490 -> -18.380
#
# Frame #139369: 	done 107 games, 	reward -18.240, 	epsilon 0.07, 	speed 14.57 f/s
#
# Best reward updated -18.380 -> -18.240
#
# Frame #142722: 	done 108 games, 	reward -18.070, 	epsilon 0.05, 	speed 14.46 f/s
#
# Best reward updated -18.240 -> -18.070
#
# Frame #145429: 	done 109 games, 	reward -17.930, 	epsilon 0.03, 	speed 14.50 f/s
#
# Best reward updated -18.070 -> -17.930
#
# Frame #148233: 	done 110 games, 	reward -17.800, 	epsilon 0.01, 	speed 14.48 f/s
#
# Best reward updated -17.930 -> -17.800
#
# Frame #151544: 	done 111 games, 	reward -17.640, 	epsilon 0.01, 	speed 14.41 f/s
#
# Best reward updated -17.800 -> -17.640
#
# Frame #155293: 	done 112 games, 	reward -17.410, 	epsilon 0.01, 	speed 14.41 f/s
#
# Best reward updated -17.640 -> -17.410
#
# Frame #158229: 	done 113 games, 	reward -17.140, 	epsilon 0.01, 	speed 14.41 f/s
#
# Best reward updated -17.410 -> -17.140
#
# Frame #161327: 	done 114 games, 	reward -16.860, 	epsilon 0.01, 	speed 14.43 f/s
#
# Best reward updated -17.140 -> -16.860
#
# Frame #164422: 	done 115 games, 	reward -16.570, 	epsilon 0.01, 	speed 14.37 f/s
#
# Best reward updated -16.860 -> -16.570
#
# Frame #168318: 	done 116 games, 	reward -16.370, 	epsilon 0.01, 	speed 14.39 f/s
#
# Best reward updated -16.570 -> -16.370
#
# Frame #171364: 	done 117 games, 	reward -16.120, 	epsilon 0.01, 	speed 14.40 f/s
#
# Best reward updated -16.370 -> -16.120
#
# Frame #174706: 	done 118 games, 	reward -15.840, 	epsilon 0.01, 	speed 14.37 f/s
#
# Best reward updated -16.120 -> -15.840
#
# Frame #177869: 	done 119 games, 	reward -15.550, 	epsilon 0.01, 	speed 14.35 f/s
#
# Best reward updated -15.840 -> -15.550
#
# Frame #180476: 	done 120 games, 	reward -15.230, 	epsilon 0.01, 	speed 14.39 f/s
#
# Best reward updated -15.550 -> -15.230
#
# Frame #183290: 	done 121 games, 	reward -14.910, 	epsilon 0.01, 	speed 14.39 f/s
#
# Best reward updated -15.230 -> -14.910
#
# Frame #185654: 	done 122 games, 	reward -14.570, 	epsilon 0.01, 	speed 14.31 f/s
#
# Best reward updated -14.910 -> -14.570
#
# Frame #188111: 	done 123 games, 	reward -14.240, 	epsilon 0.01, 	speed 14.43 f/s
#
# Best reward updated -14.570 -> -14.240
#
# Frame #190173: 	done 124 games, 	reward -13.880, 	epsilon 0.01, 	speed 14.41 f/s
#
# Best reward updated -14.240 -> -13.880
#
# Frame #191993: 	done 125 games, 	reward -13.490, 	epsilon 0.01, 	speed 14.35 f/s
#
# Best reward updated -13.880 -> -13.490
#
# Frame #194558: 	done 126 games, 	reward -13.160, 	epsilon 0.01, 	speed 14.32 f/s
#
# Best reward updated -13.490 -> -13.160
#
# Frame #196481: 	done 127 games, 	reward -12.770, 	epsilon 0.01, 	speed 14.29 f/s
#
# Best reward updated -13.160 -> -12.770
#
# Frame #199119: 	done 128 games, 	reward -12.440, 	epsilon 0.01, 	speed 14.12 f/s
#
# Best reward updated -12.770 -> -12.440
#
# Frame #200927: 	done 129 games, 	reward -12.050, 	epsilon 0.01, 	speed 13.99 f/s
#
# Best reward updated -12.440 -> -12.050
#
# Frame #202666: 	done 130 games, 	reward -11.660, 	epsilon 0.01, 	speed 14.15 f/s
#
# Best reward updated -12.050 -> -11.660
#
# Frame #204431: 	done 131 games, 	reward -11.260, 	epsilon 0.01, 	speed 14.18 f/s
#
# Best reward updated -11.660 -> -11.260
#
# Frame #206629: 	done 132 games, 	reward -10.900, 	epsilon 0.01, 	speed 14.21 f/s
#
# Best reward updated -11.260 -> -10.900
#
# Frame #209114: 	done 133 games, 	reward -10.610, 	epsilon 0.01, 	speed 14.12 f/s
#
# Best reward updated -10.900 -> -10.610
#
# Frame #211919: 	done 134 games, 	reward -10.360, 	epsilon 0.01, 	speed 14.15 f/s
#
# Best reward updated -10.610 -> -10.360
#
# Frame #213910: 	done 135 games, 	reward -9.990, 	epsilon 0.01, 	speed 14.20 f/s
#
# Best reward updated -10.360 -> -9.990
#
# Frame #215728: 	done 136 games, 	reward -9.580, 	epsilon 0.01, 	speed 14.26 f/s
#
# Best reward updated -9.990 -> -9.580
#
# Frame #217509: 	done 137 games, 	reward -9.200, 	epsilon 0.01, 	speed 14.25 f/s
#
# Best reward updated -9.580 -> -9.200
#
# Frame #219391: 	done 138 games, 	reward -8.840, 	epsilon 0.01, 	speed 14.23 f/s
#
# Best reward updated -9.200 -> -8.840
#
# Frame #221327: 	done 139 games, 	reward -8.460, 	epsilon 0.01, 	speed 14.22 f/s
#
# Best reward updated -8.840 -> -8.460
#
# Frame #223540: 	done 140 games, 	reward -8.120, 	epsilon 0.01, 	speed 14.22 f/s
#
# Best reward updated -8.460 -> -8.120
#
# Frame #225551: 	done 141 games, 	reward -7.740, 	epsilon 0.01, 	speed 14.00 f/s
#
# Best reward updated -8.120 -> -7.740
#
# Frame #227486: 	done 142 games, 	reward -7.350, 	epsilon 0.01, 	speed 14.19 f/s
#
# Best reward updated -7.740 -> -7.350
#
# Frame #229185: 	done 143 games, 	reward -6.950, 	epsilon 0.01, 	speed 14.22 f/s
#
# Best reward updated -7.350 -> -6.950
#
# Frame #231058: 	done 144 games, 	reward -6.570, 	epsilon 0.01, 	speed 14.22 f/s
#
# Best reward updated -6.950 -> -6.570
#
# Frame #233448: 	done 145 games, 	reward -6.210, 	epsilon 0.01, 	speed 14.21 f/s
#
# Best reward updated -6.570 -> -6.210
#
# Frame #235372: 	done 146 games, 	reward -5.860, 	epsilon 0.01, 	speed 14.04 f/s
#
# Best reward updated -6.210 -> -5.860
#
# Frame #237102: 	done 147 games, 	reward -5.450, 	epsilon 0.01, 	speed 14.24 f/s
#
# Best reward updated -5.860 -> -5.450
#
# Frame #238858: 	done 148 games, 	reward -5.060, 	epsilon 0.01, 	speed 14.11 f/s
#
# Best reward updated -5.450 -> -5.060
#
# Frame #240830: 	done 149 games, 	reward -4.690, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated -5.060 -> -4.690
#
# Frame #242546: 	done 150 games, 	reward -4.280, 	epsilon 0.01, 	speed 14.15 f/s
#
# Best reward updated -4.690 -> -4.280
#
# Frame #244453: 	done 151 games, 	reward -3.900, 	epsilon 0.01, 	speed 14.04 f/s
#
# Best reward updated -4.280 -> -3.900
#
# Frame #246529: 	done 152 games, 	reward -3.580, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated -3.900 -> -3.580
#
# Frame #248419: 	done 153 games, 	reward -3.210, 	epsilon 0.01, 	speed 14.15 f/s
#
# Best reward updated -3.580 -> -3.210
#
# Frame #250139: 	done 154 games, 	reward -2.820, 	epsilon 0.01, 	speed 13.97 f/s
#
# Best reward updated -3.210 -> -2.820
#
# Frame #251773: 	done 155 games, 	reward -2.430, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated -2.820 -> -2.430
#
# Frame #253626: 	done 156 games, 	reward -2.100, 	epsilon 0.01, 	speed 14.14 f/s
#
# Best reward updated -2.430 -> -2.100
#
# Frame #255639: 	done 157 games, 	reward -1.760, 	epsilon 0.01, 	speed 14.13 f/s
#
# Best reward updated -2.100 -> -1.760
#
# Frame #257366: 	done 158 games, 	reward -1.360, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated -1.760 -> -1.360
#
# Frame #259091: 	done 159 games, 	reward -0.980, 	epsilon 0.01, 	speed 14.09 f/s
#
# Best reward updated -1.360 -> -0.980
#
# Frame #261152: 	done 160 games, 	reward -0.640, 	epsilon 0.01, 	speed 14.01 f/s
#
# Best reward updated -0.980 -> -0.640
#
# Frame #263315: 	done 161 games, 	reward -0.290, 	epsilon 0.01, 	speed 14.17 f/s
#
# Best reward updated -0.640 -> -0.290
#
# Frame #264952: 	done 162 games, 	reward 0.120, 	epsilon 0.01, 	speed 14.15 f/s
#
# Best reward updated -0.290 -> 0.120
#
# Frame #266706: 	done 163 games, 	reward 0.490, 	epsilon 0.01, 	speed 14.13 f/s
#
# Best reward updated 0.120 -> 0.490
#
# Frame #268642: 	done 164 games, 	reward 0.860, 	epsilon 0.01, 	speed 14.10 f/s
#
# Best reward updated 0.490 -> 0.860
#
# Frame #270469: 	done 165 games, 	reward 1.220, 	epsilon 0.01, 	speed 14.12 f/s
#
# Best reward updated 0.860 -> 1.220
#
# Frame #272139: 	done 166 games, 	reward 1.620, 	epsilon 0.01, 	speed 14.10 f/s
#
# Best reward updated 1.220 -> 1.620
#
# Frame #274193: 	done 167 games, 	reward 1.990, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated 1.620 -> 1.990
#
# Frame #275953: 	done 168 games, 	reward 2.380, 	epsilon 0.01, 	speed 14.06 f/s
#
# Best reward updated 1.990 -> 2.380
#
# Frame #277718: 	done 169 games, 	reward 2.760, 	epsilon 0.01, 	speed 14.01 f/s
#
# Best reward updated 2.380 -> 2.760
#
# Frame #279551: 	done 170 games, 	reward 3.150, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated 2.760 -> 3.150
#
# Frame #281218: 	done 171 games, 	reward 3.500, 	epsilon 0.01, 	speed 13.98 f/s
#
# Best reward updated 3.150 -> 3.500
#
# Frame #283568: 	done 172 games, 	reward 3.780, 	epsilon 0.01, 	speed 14.04 f/s
#
# Best reward updated 3.500 -> 3.780
#
# Frame #285408: 	done 173 games, 	reward 4.130, 	epsilon 0.01, 	speed 13.99 f/s
#
# Best reward updated 3.780 -> 4.130
#
# Frame #287077: 	done 174 games, 	reward 4.510, 	epsilon 0.01, 	speed 14.05 f/s
#
# Best reward updated 4.130 -> 4.510
#
# Frame #288787: 	done 175 games, 	reward 4.890, 	epsilon 0.01, 	speed 14.08 f/s
#
# Best reward updated 4.510 -> 4.890
#
# Frame #290633: 	done 176 games, 	reward 5.270, 	epsilon 0.01, 	speed 14.02 f/s
#
# Best reward updated 4.890 -> 5.270
#
# Frame #292938: 	done 177 games, 	reward 5.580, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated 5.270 -> 5.580
#
# Frame #295633: 	done 178 games, 	reward 5.840, 	epsilon 0.01, 	speed 13.83 f/s
#
# Best reward updated 5.580 -> 5.840
#
# Frame #297631: 	done 179 games, 	reward 6.200, 	epsilon 0.01, 	speed 13.95 f/s
#
# Best reward updated 5.840 -> 6.200
#
# Frame #299487: 	done 180 games, 	reward 6.550, 	epsilon 0.01, 	speed 14.09 f/s
#
# Best reward updated 6.200 -> 6.550
#
# Frame #301206: 	done 181 games, 	reward 6.940, 	epsilon 0.01, 	speed 14.09 f/s
#
# Best reward updated 6.550 -> 6.940
#
# Frame #302948: 	done 182 games, 	reward 7.300, 	epsilon 0.01, 	speed 14.04 f/s
#
# Best reward updated 6.940 -> 7.300
#
# Frame #305335: 	done 183 games, 	reward 7.530, 	epsilon 0.01, 	speed 14.06 f/s
#
# Best reward updated 7.300 -> 7.530
#
# Frame #307106: 	done 184 games, 	reward 7.880, 	epsilon 0.01, 	speed 14.04 f/s
#
# Best reward updated 7.530 -> 7.880
#
# Frame #308990: 	done 185 games, 	reward 8.220, 	epsilon 0.01, 	speed 14.06 f/s
#
# Best reward updated 7.880 -> 8.220
#
# Frame #310957: 	done 186 games, 	reward 8.590, 	epsilon 0.01, 	speed 14.03 f/s
#
# Best reward updated 8.220 -> 8.590
#
# Frame #312642: 	done 187 games, 	reward 8.950, 	epsilon 0.01, 	speed 13.18 f/s
#
# Best reward updated 8.590 -> 8.950
#
# Frame #314969: 	done 188 games, 	reward 9.280, 	epsilon 0.01, 	speed 13.07 f/s
#
# Best reward updated 8.950 -> 9.280
#
# Frame #316663: 	done 189 games, 	reward 9.640, 	epsilon 0.01, 	speed 13.23 f/s
#
# Best reward updated 9.280 -> 9.640
#
# Frame #318293: 	done 190 games, 	reward 9.990, 	epsilon 0.01, 	speed 12.95 f/s
#
# Best reward updated 9.640 -> 9.990
#
# Frame #320150: 	done 191 games, 	reward 10.300, 	epsilon 0.01, 	speed 13.13 f/s
#
# Best reward updated 9.990 -> 10.300
#
# Frame #321816: 	done 192 games, 	reward 10.670, 	epsilon 0.01, 	speed 13.35 f/s
#
# Best reward updated 10.300 -> 10.670
#
# Frame #323791: 	done 193 games, 	reward 10.990, 	epsilon 0.01, 	speed 13.39 f/s
#
# Best reward updated 10.670 -> 10.990
#
# Frame #325516: 	done 194 games, 	reward 11.340, 	epsilon 0.01, 	speed 13.42 f/s
#
# Best reward updated 10.990 -> 11.340
#
# Frame #327387: 	done 195 games, 	reward 11.700, 	epsilon 0.01, 	speed 13.30 f/s
#
# Best reward updated 11.340 -> 11.700
#
# Frame #329099: 	done 196 games, 	reward 11.990, 	epsilon 0.01, 	speed 13.78 f/s
#
# Best reward updated 11.700 -> 11.990
#
# Frame #330904: 	done 197 games, 	reward 12.340, 	epsilon 0.01, 	speed 13.77 f/s
#
# Best reward updated 11.990 -> 12.340
#
# Frame #332698: 	done 198 games, 	reward 12.670, 	epsilon 0.01, 	speed 13.96 f/s
#
# Best reward updated 12.340 -> 12.670
#
# Frame #334765: 	done 199 games, 	reward 12.990, 	epsilon 0.01, 	speed 13.86 f/s
#
# Best reward updated 12.670 -> 12.990
#
# Frame #336398: 	done 200 games, 	reward 13.370, 	epsilon 0.01, 	speed 13.82 f/s
#
# Best reward updated 12.990 -> 13.370
#
# Frame #338633: 	done 201 games, 	reward 13.690, 	epsilon 0.01, 	speed 14.00 f/s
#
# Best reward updated 13.370 -> 13.690
#
# Frame #340464: 	done 202 games, 	reward 14.030, 	epsilon 0.01, 	speed 13.92 f/s
#
# Best reward updated 13.690 -> 14.030
#
# Frame #342249: 	done 203 games, 	reward 14.390, 	epsilon 0.01, 	speed 14.00 f/s
#
# Best reward updated 14.030 -> 14.390
#
# Frame #343915: 	done 204 games, 	reward 14.670, 	epsilon 0.01, 	speed 13.94 f/s
#
# Best reward updated 14.390 -> 14.670
#
# Frame #345545: 	done 205 games, 	reward 15.000, 	epsilon 0.01, 	speed 13.99 f/s
#
# Best reward updated 14.670 -> 15.000
#
# Frame #347272: 	done 206 games, 	reward 15.300, 	epsilon 0.01, 	speed 13.96 f/s
#
# Best reward updated 15.000 -> 15.300
#
# Frame #349082: 	done 207 games, 	reward 15.560, 	epsilon 0.01, 	speed 13.92 f/s
#
# Best reward updated 15.300 -> 15.560
#
# Frame #350880: 	done 208 games, 	reward 15.780, 	epsilon 0.01, 	speed 13.93 f/s
#
# Best reward updated 15.560 -> 15.780
#
# Frame #352606: 	done 209 games, 	reward 16.040, 	epsilon 0.01, 	speed 13.85 f/s
#
# Best reward updated 15.780 -> 16.040
#
# Frame #354318: 	done 210 games, 	reward 16.320, 	epsilon 0.01, 	speed 13.95 f/s
#
# Best reward updated 16.040 -> 16.320
#
# Frame #356108: 	done 211 games, 	reward 16.560, 	epsilon 0.01, 	speed 13.95 f/s
#
# Best reward updated 16.320 -> 16.560
#
# Frame #357835: 	done 212 games, 	reward 16.730, 	epsilon 0.01, 	speed 13.92 f/s
#
# Best reward updated 16.560 -> 16.730
#
# Frame #359583: 	done 213 games, 	reward 16.850, 	epsilon 0.01, 	speed 13.94 f/s
#
# Best reward updated 16.730 -> 16.850
#
# Frame #361360: 	done 214 games, 	reward 16.970, 	epsilon 0.01, 	speed 13.90 f/s
#
# Best reward updated 16.850 -> 16.970
#
# Frame #363776: 	done 215 games, 	reward 17.020, 	epsilon 0.01, 	speed 13.18 f/s
#
# Best reward updated 16.970 -> 17.020
#
# Frame #365408: 	done 216 games, 	reward 17.220, 	epsilon 0.01, 	speed 13.62 f/s
#
# Best reward updated 17.020 -> 17.220
#
# Frame #367280: 	done 217 games, 	reward 17.360, 	epsilon 0.01, 	speed 13.62 f/s
#
# Best reward updated 17.220 -> 17.360
#
# Frame #369120: 	done 218 games, 	reward 17.480, 	epsilon 0.01, 	speed 14.03 f/s
#
# Best reward updated 17.360 -> 17.480
#
# Frame #370750: 	done 219 games, 	reward 17.610, 	epsilon 0.01, 	speed 13.83 f/s
#
# Best reward updated 17.480 -> 17.610
#
# Frame #372468: 	done 220 games, 	reward 17.670, 	epsilon 0.01, 	speed 13.33 f/s
#
# Best reward updated 17.610 -> 17.670
#
# Frame #374173: 	done 221 games, 	reward 17.750, 	epsilon 0.01, 	speed 12.90 f/s
#
# Best reward updated 17.670 -> 17.750
#
# Frame #376052: 	done 222 games, 	reward 17.780, 	epsilon 0.01, 	speed 13.29 f/s
#
# Best reward updated 17.750 -> 17.780
#
# Frame #377746: 	done 223 games, 	reward 17.860, 	epsilon 0.01, 	speed 13.60 f/s
#
# Best reward updated 17.780 -> 17.860
#
# Frame #379427: 	done 224 games, 	reward 17.910, 	epsilon 0.01, 	speed 13.49 f/s
#
# Best reward updated 17.860 -> 17.910
#
# Frame #381119: 	done 225 games, 	reward 17.930, 	epsilon 0.01, 	speed 13.21 f/s
#
# Best reward updated 17.910 -> 17.930
#
# Frame #383921: 	done 226 games, 	reward 17.900, 	epsilon 0.01, 	speed 12.32 f/s
# Frame #385699: 	done 227 games, 	reward 17.900, 	epsilon 0.01, 	speed 12.60 f/s
# Frame #387613: 	done 228 games, 	reward 17.960, 	epsilon 0.01, 	speed 11.57 f/s
#
# Best reward updated 17.930 -> 17.960
#
# Frame #389246: 	done 229 games, 	reward 17.980, 	epsilon 0.01, 	speed 11.20 f/s
#
# Best reward updated 17.960 -> 17.980
#
# Frame #390988: 	done 230 games, 	reward 17.980, 	epsilon 0.01, 	speed 11.04 f/s
# Frame #392619: 	done 231 games, 	reward 18.000, 	epsilon 0.01, 	speed 10.20 f/s
#
# Best reward updated 17.980 -> 18.000
#
# Frame #394471: 	done 232 games, 	reward 18.010, 	epsilon 0.01, 	speed 12.73 f/s
#
# Best reward updated 18.000 -> 18.010
#
# Frame #396101: 	done 233 games, 	reward 18.130, 	epsilon 0.01, 	speed 13.17 f/s
#
# Best reward updated 18.010 -> 18.130
#
# Frame #397827: 	done 234 games, 	reward 18.280, 	epsilon 0.01, 	speed 13.78 f/s
#
# Best reward updated 18.130 -> 18.280
#
# Frame #399664: 	done 235 games, 	reward 18.320, 	epsilon 0.01, 	speed 13.73 f/s
#
# Best reward updated 18.280 -> 18.320
#
# Frame #401614: 	done 236 games, 	reward 18.300, 	epsilon 0.01, 	speed 13.86 f/s
# Frame #403384: 	done 237 games, 	reward 18.290, 	epsilon 0.01, 	speed 13.70 f/s
# Frame #405456: 	done 238 games, 	reward 18.300, 	epsilon 0.01, 	speed 13.76 f/s
# Frame #407087: 	done 239 games, 	reward 18.330, 	epsilon 0.01, 	speed 13.62 f/s
#
# Best reward updated 18.320 -> 18.330
#
# Frame #408835: 	done 240 games, 	reward 18.390, 	epsilon 0.01, 	speed 13.58 f/s
#
# Best reward updated 18.330 -> 18.390
#
# Frame #410501: 	done 241 games, 	reward 18.420, 	epsilon 0.01, 	speed 13.74 f/s
#
# Best reward updated 18.390 -> 18.420
#
# Frame #412291: 	done 242 games, 	reward 18.430, 	epsilon 0.01, 	speed 13.97 f/s
#
# Best reward updated 18.420 -> 18.430
#
# Frame #413921: 	done 243 games, 	reward 18.440, 	epsilon 0.01, 	speed 14.05 f/s
#
# Best reward updated 18.430 -> 18.440
#
# Frame #415743: 	done 244 games, 	reward 18.440, 	epsilon 0.01, 	speed 13.91 f/s
# Frame #417513: 	done 245 games, 	reward 18.490, 	epsilon 0.01, 	speed 13.83 f/s
#
# Best reward updated 18.440 -> 18.490
#
# Frame #419202: 	done 246 games, 	reward 18.520, 	epsilon 0.01, 	speed 13.96 f/s
#
# Best reward updated 18.490 -> 18.520
#
# Frame #420832: 	done 247 games, 	reward 18.530, 	epsilon 0.01, 	speed 13.99 f/s
#
# Best reward updated 18.520 -> 18.530
#
# Frame #422675: 	done 248 games, 	reward 18.530, 	epsilon 0.01, 	speed 14.00 f/s
# Frame #424378: 	done 249 games, 	reward 18.550, 	epsilon 0.01, 	speed 13.94 f/s
#
# Best reward updated 18.530 -> 18.550
#
# Frame #426045: 	done 250 games, 	reward 18.540, 	epsilon 0.01, 	speed 13.53 f/s
# Frame #427764: 	done 251 games, 	reward 18.560, 	epsilon 0.01, 	speed 13.33 f/s
#
# Best reward updated 18.550 -> 18.560
#
# Frame #429453: 	done 252 games, 	reward 18.610, 	epsilon 0.01, 	speed 13.09 f/s
#
# Best reward updated 18.560 -> 18.610
#
# Frame #431136: 	done 253 games, 	reward 18.620, 	epsilon 0.01, 	speed 11.23 f/s
#
# Best reward updated 18.610 -> 18.620
#
# Frame #432857: 	done 254 games, 	reward 18.620, 	epsilon 0.01, 	speed 12.66 f/s
# Frame #434492: 	done 255 games, 	reward 18.620, 	epsilon 0.01, 	speed 12.39 f/s
# Frame #436372: 	done 256 games, 	reward 18.620, 	epsilon 0.01, 	speed 12.49 f/s
# Frame #438018: 	done 257 games, 	reward 18.700, 	epsilon 0.01, 	speed 13.51 f/s
#
# Best reward updated 18.620 -> 18.700
#
# Frame #439808: 	done 258 games, 	reward 18.700, 	epsilon 0.01, 	speed 12.71 f/s
# Frame #441721: 	done 259 games, 	reward 18.680, 	epsilon 0.01, 	speed 13.42 f/s
# Frame #443625: 	done 260 games, 	reward 18.690, 	epsilon 0.01, 	speed 12.38 f/s
# Frame #445366: 	done 261 games, 	reward 18.740, 	epsilon 0.01, 	speed 13.61 f/s
#
# Best reward updated 18.700 -> 18.740
#
# Frame #447172: 	done 262 games, 	reward 18.720, 	epsilon 0.01, 	speed 13.68 f/s
# Frame #449014: 	done 263 games, 	reward 18.710, 	epsilon 0.01, 	speed 14.00 f/s
# Frame #450680: 	done 264 games, 	reward 18.740, 	epsilon 0.01, 	speed 14.12 f/s
# Frame #452407: 	done 265 games, 	reward 18.760, 	epsilon 0.01, 	speed 14.11 f/s
#
# Best reward updated 18.740 -> 18.760
#
# Frame #454255: 	done 266 games, 	reward 18.760, 	epsilon 0.01, 	speed 14.17 f/s
# Frame #456203: 	done 267 games, 	reward 18.770, 	epsilon 0.01, 	speed 14.10 f/s
#
# Best reward updated 18.760 -> 18.770
#
# Frame #457982: 	done 268 games, 	reward 18.770, 	epsilon 0.01, 	speed 14.14 f/s
# Frame #459651: 	done 269 games, 	reward 18.780, 	epsilon 0.01, 	speed 14.10 f/s
#
# Best reward updated 18.770 -> 18.780
#
# Frame #461524: 	done 270 games, 	reward 18.790, 	epsilon 0.01, 	speed 13.96 f/s
#
# Best reward updated 18.780 -> 18.790
#
# Frame #463191: 	done 271 games, 	reward 18.790, 	epsilon 0.01, 	speed 14.13 f/s
# Frame #465010: 	done 272 games, 	reward 18.890, 	epsilon 0.01, 	speed 13.88 f/s
#
# Best reward updated 18.790 -> 18.890
#
# Frame #467136: 	done 273 games, 	reward 18.870, 	epsilon 0.01, 	speed 13.91 f/s
# Frame #468917: 	done 274 games, 	reward 18.860, 	epsilon 0.01, 	speed 13.96 f/s
# Frame #470583: 	done 275 games, 	reward 18.860, 	epsilon 0.01, 	speed 13.88 f/s
# Frame #472363: 	done 276 games, 	reward 18.870, 	epsilon 0.01, 	speed 14.11 f/s
# Frame #474029: 	done 277 games, 	reward 18.920, 	epsilon 0.01, 	speed 14.05 f/s
#
# Best reward updated 18.890 -> 18.920
#
# Frame #476060: 	done 278 games, 	reward 18.970, 	epsilon 0.01, 	speed 14.14 f/s
#
# Best reward updated 18.920 -> 18.970
#
# Frame #477956: 	done 279 games, 	reward 18.980, 	epsilon 0.01, 	speed 14.16 f/s
#
# Best reward updated 18.970 -> 18.980
#
# Frame #479710: 	done 280 games, 	reward 18.990, 	epsilon 0.01, 	speed 13.69 f/s
#
# Best reward updated 18.980 -> 18.990
#
# Frame #481434: 	done 281 games, 	reward 19.000, 	epsilon 0.01, 	speed 14.07 f/s
#
# Best reward updated 18.990 -> 19.000
#
# Frame #483064: 	done 282 games, 	reward 19.020, 	epsilon 0.01, 	speed 13.78 f/s
#
# Best reward updated 19.000 -> 19.020
#
# Solved in 483064 frames!

# %% [markdown]
# <br>
#
# ### Final Screen of Training
#
# <img src="recordings/training_final_screen.png" style="height:300px">
#
# <br>
#
# ### TensorBoard

# %%
# !tensorboard dev upload --logdir='07_dqn/runs' --name='07_dqn_pong'

# %% [markdown]
# <img src="runs/epsilon.png" style="height:300px">
#
# <img src="runs/reward_100.png" style="height:300px">
#
# <img src="runs/reward.png" style="height:300px">
#
# <img src="runs/speed.png" style="height:300px">
#
# <br>
