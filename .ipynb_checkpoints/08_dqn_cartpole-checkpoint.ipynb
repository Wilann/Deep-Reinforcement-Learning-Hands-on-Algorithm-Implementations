# %% [markdown]
# # [08] Deep Q-Learning in Cartpole
#
# ### Imports & Constants

# %%
import gym
import ptan
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


HIDDEN_SIZE = 128
BATCH_SIZE = 16
TGT_NET_SYNC = 10
GAMMA = 0.9
REPLAY_SIZE = 1000
LR = 1e-3
EPS_DECAY=0.99

# %% [markdown]
# <br>
#
# ### Network & Helper Function

# %%
class Net(nn.Module):
    '''Neural Net'''
    
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x.float())


@torch.no_grad()
def unpack_batch(batch, net, gamma):
    '''
    Unpacks a batch of observations into:
    - `states`
    - `actions`
    - `rewards`
    - `done_masks`
    - `last_states`
    and converts some into tensors 
    '''
    
    states = []
    actions = []
    rewards = []
    done_masks = []
    last_states = []
    
    # Split up batches 
    for exp in batch:
        states.append(exp.state)
        actions.append(exp.action)
        rewards.append(exp.reward)
        done_masks.append(exp.last_state is None)
        if exp.last_state is None:
            last_states.append(exp.state)
        else:
            last_states.append(exp.last_state)

    # Convert to tensors 
    states_v = torch.tensor(states)
    actions_v = torch.tensor(actions)
    rewards_v = torch.tensor(rewards)
    last_states_v = torch.tensor(last_states)
    
    # Q-Value of last state
    last_state_q_v = net(last_states_v)
    
    # Best Q-value of last state 
    best_last_q_v = torch.max(last_state_q_v, dim=1)[0]
    
    # Best Q-value of last state of last observation is 0
    best_last_q_v[done_masks] = 0.0
    
    # Return states, actions, and bellman approximation
    return states_v, actions_v, best_last_q_v * gamma + rewards_v

# %% [markdown]
# <br>
#
# ### Main

# %%
# Directories 
model_dir = 'models/'
rec_dir = 'recordings/'

# Environment info 
env = gym.make("CartPole-v0")
env = gym.wrappers.Monitor(env, rec_dir, force=True)
obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

# Network & Target Network 
net = Net(obs_size, HIDDEN_SIZE, n_actions)
tgt_net = ptan.agent.TargetNet(net)

# Selector 
selector = ptan.actions.ArgmaxActionSelector()
selector = ptan.actions.EpsilonGreedyActionSelector(epsilon=1, selector=selector)

# Agent 
agent = ptan.agent.DQNAgent(net, selector)

# Experience Source 
exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=GAMMA)

# Replay Buffer 
buffer = ptan.experience.ExperienceReplayBuffer(exp_source, buffer_size=REPLAY_SIZE)

optimizer = optim.Adam(net.parameters(), LR)
step = 0  # Keeps track of number of training iterations 
episode = 0 
solved = False 

while True:
    step += 1
    
    # Get a sample from the experience source & check for finished episode 
    buffer.populate(1)

    # 
    for reward, steps in exp_source.pop_rewards_steps():
        episode += 1
        print("Step %d: episode %d done, reward=%.3f, epsilon=%.2f" % (step, episode, reward, selector.epsilon))
        solved = reward > 150
    
    # If environment is solved 
    if solved:
        print("Environment solved!")
        break

    # 
    if len(buffer) < 2*BATCH_SIZE:
        continue

    # Sample `BATCH_SIZE` experiences from the buffer & unpack them 
    batch = buffer.sample(BATCH_SIZE)
    states_v, actions_v, tgt_q_v = unpack_batch(batch, tgt_net.target_model, GAMMA)
    
    # Get Q-values 
    optimizer.zero_grad()
    q_v = net(states_v)
    q_v = q_v.gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    
    # Calculate loss & backpropagate 
    loss_v = F.mse_loss(q_v, tgt_q_v)
    loss_v.backward()
    optimizer.step()
    
    # Decay epsilon in action selector 
    # Note: In this case, `epsilon` decays to 0 at training step 500
    selector.epsilon *= EPS_DECAY

    # Sync target network weights every 10 training iterations 
    if step % TGT_NET_SYNC == 0:
        tgt_net.sync()
# Out:
# Step 15: episode 1 done, reward=14.000, epsilon=1.00
# Step 28: episode 2 done, reward=13.000, epsilon=1.00
# Step 43: episode 3 done, reward=15.000, epsilon=0.90
# Step 77: episode 4 done, reward=34.000, epsilon=0.64
# Step 94: episode 5 done, reward=17.000, epsilon=0.54
# Step 109: episode 6 done, reward=15.000, epsilon=0.46
# Step 126: episode 7 done, reward=17.000, epsilon=0.39
# Step 136: episode 8 done, reward=10.000, epsilon=0.35
# Step 146: episode 9 done, reward=10.000, epsilon=0.32
# Step 160: episode 10 done, reward=14.000, epsilon=0.28
# Step 171: episode 11 done, reward=11.000, epsilon=0.25
# Step 183: episode 12 done, reward=12.000, epsilon=0.22
# Step 195: episode 13 done, reward=12.000, epsilon=0.19
# Step 207: episode 14 done, reward=12.000, epsilon=0.17
# Step 218: episode 15 done, reward=11.000, epsilon=0.15
# Step 227: episode 16 done, reward=9.000, epsilon=0.14
# Step 237: episode 17 done, reward=10.000, epsilon=0.13
# Step 247: episode 18 done, reward=10.000, epsilon=0.12
# Step 257: episode 19 done, reward=10.000, epsilon=0.10
# Step 269: episode 20 done, reward=12.000, epsilon=0.09
# Step 279: episode 21 done, reward=10.000, epsilon=0.08
# Step 289: episode 22 done, reward=10.000, epsilon=0.08
# Step 299: episode 23 done, reward=10.000, epsilon=0.07
# Step 307: episode 24 done, reward=8.000, epsilon=0.06
# Step 318: episode 25 done, reward=11.000, epsilon=0.06
# Step 332: episode 26 done, reward=14.000, epsilon=0.05
# Step 345: episode 27 done, reward=13.000, epsilon=0.04
# Step 355: episode 28 done, reward=10.000, epsilon=0.04
# Step 364: episode 29 done, reward=9.000, epsilon=0.04
# Step 375: episode 30 done, reward=11.000, epsilon=0.03
# Step 388: episode 31 done, reward=13.000, epsilon=0.03
# Step 403: episode 32 done, reward=15.000, epsilon=0.02
# Step 416: episode 33 done, reward=13.000, epsilon=0.02
# Step 431: episode 34 done, reward=15.000, epsilon=0.02
# Step 440: episode 35 done, reward=9.000, epsilon=0.02
# Step 451: episode 36 done, reward=11.000, epsilon=0.01
# Step 460: episode 37 done, reward=9.000, epsilon=0.01
# Step 470: episode 38 done, reward=10.000, epsilon=0.01
# Step 479: episode 39 done, reward=9.000, epsilon=0.01
# Step 487: episode 40 done, reward=8.000, epsilon=0.01
# Step 498: episode 41 done, reward=11.000, epsilon=0.01
# Step 517: episode 42 done, reward=19.000, epsilon=0.01
# Step 535: episode 43 done, reward=18.000, epsilon=0.01
# Step 546: episode 44 done, reward=11.000, epsilon=0.01
# Step 559: episode 45 done, reward=13.000, epsilon=0.01
# Step 570: episode 46 done, reward=11.000, epsilon=0.00
# Step 595: episode 47 done, reward=25.000, epsilon=0.00
# Step 617: episode 48 done, reward=22.000, epsilon=0.00
# Step 636: episode 49 done, reward=19.000, epsilon=0.00
# Step 664: episode 50 done, reward=28.000, epsilon=0.00
# Step 700: episode 51 done, reward=36.000, epsilon=0.00
# Step 724: episode 52 done, reward=24.000, epsilon=0.00
# Step 744: episode 53 done, reward=20.000, epsilon=0.00
# Step 775: episode 54 done, reward=31.000, epsilon=0.00
# Step 805: episode 55 done, reward=30.000, epsilon=0.00
# Step 834: episode 56 done, reward=29.000, epsilon=0.00
# Step 861: episode 57 done, reward=27.000, epsilon=0.00
# Step 883: episode 58 done, reward=22.000, epsilon=0.00
# Step 904: episode 59 done, reward=21.000, epsilon=0.00
# Step 936: episode 60 done, reward=32.000, epsilon=0.00
# Step 968: episode 61 done, reward=32.000, epsilon=0.00
# Step 979: episode 62 done, reward=11.000, epsilon=0.00
# Step 1000: episode 63 done, reward=21.000, epsilon=0.00
# Step 1050: episode 64 done, reward=50.000, epsilon=0.00
# Step 1085: episode 65 done, reward=35.000, epsilon=0.00
# Step 1103: episode 66 done, reward=18.000, epsilon=0.00
# Step 1175: episode 67 done, reward=72.000, epsilon=0.00
# Step 1221: episode 68 done, reward=46.000, epsilon=0.00
# Step 1267: episode 69 done, reward=46.000, epsilon=0.00
# Step 1297: episode 70 done, reward=30.000, epsilon=0.00
# Step 1324: episode 71 done, reward=27.000, epsilon=0.00
# Step 1354: episode 72 done, reward=30.000, epsilon=0.00
# Step 1379: episode 73 done, reward=25.000, epsilon=0.00
# Step 1424: episode 74 done, reward=45.000, epsilon=0.00
# Step 1489: episode 75 done, reward=65.000, epsilon=0.00
# Step 1531: episode 76 done, reward=42.000, epsilon=0.00
# Step 1562: episode 77 done, reward=31.000, epsilon=0.00
# Step 1618: episode 78 done, reward=56.000, epsilon=0.00
# Step 1648: episode 79 done, reward=30.000, epsilon=0.00
# Step 1737: episode 80 done, reward=89.000, epsilon=0.00
# Step 1793: episode 81 done, reward=56.000, epsilon=0.00
# Step 1823: episode 82 done, reward=30.000, epsilon=0.00
# Step 1859: episode 83 done, reward=36.000, epsilon=0.00
# Step 1901: episode 84 done, reward=42.000, epsilon=0.00
# Step 1940: episode 85 done, reward=39.000, epsilon=0.00
# Step 1976: episode 86 done, reward=36.000, epsilon=0.00
# Step 2003: episode 87 done, reward=27.000, epsilon=0.00
# Step 2039: episode 88 done, reward=36.000, epsilon=0.00
# Step 2067: episode 89 done, reward=28.000, epsilon=0.00
# Step 2098: episode 90 done, reward=31.000, epsilon=0.00
# Step 2129: episode 91 done, reward=31.000, epsilon=0.00
# Step 2197: episode 92 done, reward=68.000, epsilon=0.00
# Step 2235: episode 93 done, reward=38.000, epsilon=0.00
# Step 2290: episode 94 done, reward=55.000, epsilon=0.00
# Step 2398: episode 95 done, reward=108.000, epsilon=0.00
# Step 2428: episode 96 done, reward=30.000, epsilon=0.00
# Step 2459: episode 97 done, reward=31.000, epsilon=0.00
# Step 2495: episode 98 done, reward=36.000, epsilon=0.00
# Step 2533: episode 99 done, reward=38.000, epsilon=0.00
# Step 2570: episode 100 done, reward=37.000, epsilon=0.00
# Step 2621: episode 101 done, reward=51.000, epsilon=0.00
# Step 2657: episode 102 done, reward=36.000, epsilon=0.00
# Step 2690: episode 103 done, reward=33.000, epsilon=0.00
# Step 2739: episode 104 done, reward=49.000, epsilon=0.00
# Step 2780: episode 105 done, reward=41.000, epsilon=0.00
# Step 2820: episode 106 done, reward=40.000, epsilon=0.00
# Step 2872: episode 107 done, reward=52.000, epsilon=0.00
# Step 2925: episode 108 done, reward=53.000, epsilon=0.00
# Step 2987: episode 109 done, reward=62.000, epsilon=0.00
# Step 3035: episode 110 done, reward=48.000, epsilon=0.00
# Step 3088: episode 111 done, reward=53.000, epsilon=0.00
# Step 3151: episode 112 done, reward=63.000, epsilon=0.00
# Step 3191: episode 113 done, reward=40.000, epsilon=0.00
# Step 3230: episode 114 done, reward=39.000, epsilon=0.00
# Step 3289: episode 115 done, reward=59.000, epsilon=0.00
# Step 3335: episode 116 done, reward=46.000, epsilon=0.00
# Step 3394: episode 117 done, reward=59.000, epsilon=0.00
# Step 3451: episode 118 done, reward=57.000, epsilon=0.00
# Step 3523: episode 119 done, reward=72.000, epsilon=0.00
# Step 3604: episode 120 done, reward=81.000, epsilon=0.00
# Step 3674: episode 121 done, reward=70.000, epsilon=0.00
# Step 3794: episode 122 done, reward=120.000, epsilon=0.00
# Step 3994: episode 123 done, reward=200.000, epsilon=0.00
# Environment solved!

# %% [markdown]
# <br>
